# %% [markdown]
# # Chat Analysis
#
# This notebook has the chat analysis for the data provided recently
#
# Here's a small example of the stuff you can accomplish - run the codeblock below to get a count of all the rows we have in our database

# %%
# %matplotlib inline
import base

base.conversation_abandoned_chart()
# Out:
# Total number of 24/7 chats that were open are
# 2164
# Out that number, we can see that only a proportion of them actually started
# started      1435
# abandoned     729
# Name: 24/7 Usage, dtype: int64
